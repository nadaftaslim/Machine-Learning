# %% [markdown]
# <a href="https://colab.research.google.com/github/nadaftaslim/Machine-Learning/blob/main/Copy_of_simple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/1. Simple linear regression.csv')

# %%
data.head
# Out:
# <bound method NDFrame.head of     ï»¿SAT   GPA
# 0     1714  2.40
# 1     1664  2.52
# 2     1760  2.54
# 3     1685  2.74
# 4     1693  2.83
# ..     ...   ...
# 79    1936  3.71
# 80    1810  3.71
# 81    1987  3.73
# 82    1962  3.76
# 83    2050  3.81
#
# [84 rows x 2 columns]>

# %%
data.describe
# Out:
# <bound method NDFrame.describe of     ï»¿SAT   GPA
# 0     1714  2.40
# 1     1664  2.52
# 2     1760  2.54
# 3     1685  2.74
# 4     1693  2.83
# ..     ...   ...
# 79    1936  3.71
# 80    1810  3.71
# 81    1987  3.73
# 82    1962  3.76
# 83    2050  3.81
#
# [84 rows x 2 columns]>

# %%
y=data['GPA']
x=data['ï»¿SAT']
plt.scatter(x,y)
plt.xlabel('SAT ',fontsize=10)
plt.ylabel('GPA',fontsize=10)
plt.show()

# %%
plt.scatter(x,y)
yhat=0.2750+0.0017*x
fig=plt.plot(x,yhat,lw=4,color='red',label='regression')
plt.show()
